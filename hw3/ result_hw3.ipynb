# %%
#call binomial tree
import math
import numpy as np

S0 = int(input("S0 = ",))
N = int(input("N = ",))
u = float(input("u = ",))
d = float(input("d = ",))
r = float(input("r = ",))
X = int(input("X = ",))
p = int(input("p =",))
R = 2.71828**r

#count stock price of every period, save in list a
a = []
for i in range(N + 1): 
    #print("N =",i) 
    list = []
    for j in range(i + 1):
        stock = (u ** (i - j)) * (d ** j) * S0 
        list.append(stock)
        #print(stock)
    print("stock price in period",i,list)
    a.append(list)
print("stock price every period:",a)


#select the last period stock price,  call value of last period = max(0, S0-X)
call_value = []
for i in range(N + 1):
    call = max(0, a[N][i]-X)
    call_value.append(call)
    #print(call)
print("call value of last period:",call_value)


#using formula, backward induction to get call price of previous period
M = N
value = []
value.append(call_value)
for i in range(N):
    prev_option = []
    for j in range(M):
        #print(i,j)
        option = (p*call_value[j] + (1-p)*call_value[j+1])/1.2
        prev_option.append(option)
        #print(prev_option)
    M -= 1
    call_value = prev_option
    print("call value in period",N-i-1,call_value)
    value.append(call_value)
print("call value in every(backward) period:",value)


#call_array = np.array(value)
#print(call_array)
#call_matrix = np.asmatrix(call_array)
#print(call_matrix)
# Out:
# stock price in period 0 [160.0]
# stock price in period 1 [240.0, 80.0]
# stock price in period 2 [360.0, 120.0, 40.0]
# stock price in period 3 [540.0, 180.0, 60.0, 20.0]
# stock price every period: [[160.0], [240.0, 80.0], [360.0, 120.0, 40.0], [540.0, 180.0, 60.0, 20.0]]
# call value of last period: [390.0, 30.0, 0, 0]
# call value in period 2 [235.0, 17.5, 0.0]
# call value in period 1 [141.45833333333334, 10.208333333333334]
# call value in period 0 [85.06944444444444]
# call value in every(backward) period: [[390.0, 30.0, 0, 0], [235.0, 17.5, 0.0], [141.45833333333334, 10.208333333333334], [85.06944444444444]]

# %%
#put binomial tree
import math
import numpy as np

S0 = 160#int(input("S0 = ",))
N = 3#int(input("N = ",))
u = 1.5#float(input("u = ",))
d = 0.5#float(input("d = ",))
r = 0.18232#float(input("r = ",))
X = 150#int(input("X = ",))
p = 0.7#int(input("p =",))
R = 2.71828**r

#count stock price of every period, save in list a
a = []
for i in range(N + 1): 
    #print("N =",i) 
    list = []
    for j in range(i + 1):
        stock = (d ** (i - j)) * (u ** j) * S0 
        list.append(stock)
        #print(stock)
    print("stock price in period",i,list)
    a.append(list)
print("stock price every period:",a)


#select the last period stock price,  put value of last period = max(0, X-S0)
put_value = []
for i in range(N + 1):
    put = max(0, X-a[N][i])
    put_value.append(put)
    #print(put)
print("put value of last period:",put_value)


#using formula, backward induction to get put price of previous period
M = N
value = []
value.append(put_value)
for i in range(N):
    prev_option = []
    for j in range(M):
        #print(i,j)
        option = ((1-p)*put_value[j] + (p)*put_value[j+1])/R
        prev_option.append(option)
        #print(prev_option)
    M -= 1
    put_value = prev_option
    print("put value in period",N-i-1,put_value)
    value.append(put_value)
print("put value in every(backward) period:",value)
# Out:
# stock price in period 0 [160.0]
# stock price in period 1 [80.0, 240.0]
# stock price in period 2 [40.0, 120.0, 360.0]
# stock price in period 3 [20.0, 60.0, 180.0, 540.0]
# stock price every period: [[160.0], [80.0, 240.0], [40.0, 120.0, 360.0], [20.0, 60.0, 180.0, 540.0]]
# put value of last period: [130.0, 90.0, 0, 0]
# put value in period 2 [85.00014275183972, 22.500037787251692, 0.0]
# put value in period 1 [34.37511546114379, 5.625018893641712]
# put value in period 0 [11.87505982991566]
# put value in every(backward) period: [[130.0, 90.0, 0, 0], [85.00014275183972, 22.500037787251692, 0.0], [34.37511546114379, 5.625018893641712], [11.87505982991566]]
